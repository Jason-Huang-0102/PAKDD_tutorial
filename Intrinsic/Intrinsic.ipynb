# %% [markdown]
# # Import library and setting parameter

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %cd /content/gdrive/MyDrive/PAKDD/Intrinsic
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/PAKDD/Intrinsic

# %%
import numpy as np
import os
import cv2

corner = 7 # how many blocks in chessboard
block = 14 # the width of each block in real world (mm)
resolution = [1440, 1080]

# %% [markdown]
# # Get the Intersection of chessboard

# %%
rootdir = os.getcwd()
imgPath = os.path.join(rootdir, '16124946')

objp = np.zeros((corner*corner,3), np.float32)
objp[:,:2] = np.mgrid[0:corner, 0:corner].T.reshape(-1,2)
objp = objp * block

# get the chessboard image
images = []
for filename in os.listdir(imgPath):
  print(filename)
  fullpath = os.path.join(imgPath, filename)
  if filename.startswith('chessboard_') and filename.endswith('.jpg'):
      images.append(fullpath)

print('Start finding chessboard corners...')
objpoints = [] # 3d points in real world space
imgpoints = [] # 2d points in image plane.
for idx, fname in enumerate(images):
  img = cv2.imread(fname)
  img = cv2.resize(img, (resolution[0], resolution[1]), interpolation=cv2.INTER_AREA)
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  ret, corners = cv2.findChessboardCorners(gray, (corner, corner), None)
  if ret == True:
      objpoints.append(objp)
      imgpoints.append(corners)
img_size = (img.shape[1], img.shape[0])
# Out:
# chessboard_0013.jpg
# chessboard_0017.jpg
# chessboard_0004.jpg
# chessboard_0011.jpg
# chessboard_0015.jpg
# chessboard_0002.jpg
# chessboard_0012.jpg
# chessboard_0016.jpg
# chessboard_0003.jpg
# chessboard_0000.jpg
# chessboard_0006.jpg
# chessboard_0008.jpg
# chessboard_0001.jpg
# chessboard_0007.jpg
# chessboard_0010.jpg
# chessboard_0019.jpg
# chessboard_0005.jpg
# chessboard_0018.jpg
# chessboard_0014.jpg
# chessboard_0009.jpg
# Start finding chessboard corners...

# %% [markdown]
# # Calculate camera intrinsic

# %%
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, img_size,None,None)

print("Intrinsic: {}".format(mtx))
print("Dist: {}".format(dist))
# Out:
# Intrinsic: [[1.27055855e+03 0.00000000e+00 6.86666788e+02]
#  [0.00000000e+00 1.26818197e+03 5.35773888e+02]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]]
# Dist: [[-5.22832991e-01  3.38204494e-01 -3.70890750e-04  3.92867333e-04
#   -1.32748930e-01]]
