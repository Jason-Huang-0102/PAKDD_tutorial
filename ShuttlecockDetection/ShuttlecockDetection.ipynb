# %% [markdown]
# # TrackNetV2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import and Download Model and weights

# %%
# !git clone https://github.com/wolfyeva/TrackNetV2.git
# Out:
# Cloning into 'TrackNetV2'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 41 (delta 13), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (41/41), 36.02 KiB | 1.29 MiB/s, done.

# %%
# %cd /content/TrackNetV2/models
# Out:
# /content/TrackNetV2/models

# %%
# !gdown --id 1_mrzOAAGsn2DAI7T1igJ9pYKabV278lb # Download pre-trained weights
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1_mrzOAAGsn2DAI7T1igJ9pYKabV278lb
# To: /content/TrackNetV2/models/model_best.pt
# 100% 122M/122M [00:00<00:00, 143MB/s]

# %%
# %cd /content/TrackNetV2
# Out:
# /content/TrackNetV2

# %%
# !pip install parse
# !pip install --pre piexif
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24589 sha256=a73f69179c3d531f333ad43bdb01a397d167cc36138d2cc1493f4bb0cdd68688
#   Stored in directory: /root/.cache/pip/wheels/70/4b/f0/eaf5a8de646d8676dc25caa01949b9f9d883b8fa2efb435bc3
# Successfully built parse
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## Download Input Video

# %%
# !gdown --id 1hzcyBv8nPjkQdffpeOTwMMFdnHlr4L5D
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1hzcyBv8nPjkQdffpeOTwMMFdnHlr4L5D
# To: /content/TrackNetV2/1_00_01.mp4
# 100% 2.39M/2.39M [00:00<00:00, 182MB/s]

# %% [markdown]
# ## Prediction & Output video and .csv file

# %%
# !python3 predict.py  --video_file /content/TrackNetV2/1_00_01.mp4 \
            --model_file models/model_best.pt \
            --save_dir prediction
# !python3 predict.py  --video_file /content/drive/MyDrive/PAKDD/ShuttlecockDetection/1_00_01.mp4 \
#             --model_file /content/drive/MyDrive/PAKDD/ShuttlecockDetection/model_best.pt \
#             --save_dir /content/drive/MyDrive/PAKDD/ShuttlecockDetection/prediction
# Out:
# 2023-05-04 07:16:09.959740: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-04 07:16:11.203508: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Number of sampled frames: 0
# Number of sampled frames: 30
# Number of sampled frames: 60
# Number of sampled frames: 90
# Number of sampled frames: 120
# Number of sampled frames: 150
# Number of sampled frames: 180
# Number of sampled frames: 210
# Number of sampled frames: 240
# Number of sampled frames: 270
# Number of sampled frames: 300
# Number of sampled frames: 330
# Number of sampled frames: 360
# Number of sampled frames: 390
# Number of sampled frames: 420
# Number of sampled frames: 421
# Done.

# %%
# !python3 show_trajectory.py --video_file /content/TrackNetV2/1_00_01.mp4 \
               --csv_file /content/TrackNetV2/prediction/1_00_01_ball.csv \
               --save_dir prediction
# !python3 show_trajectory.py --video_file /content/TrackNetV2/1_00_01.mp4 \
#                --csv_file /content/TrackNetV2/prediction/1_00_01_ball.csv \
#                --save_dir prediction
# Out:
# 2023-05-03 07:25:53.315190: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-03 07:25:54.220110: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# total frames: 342
# Done
